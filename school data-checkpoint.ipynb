# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_palette("husl")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Downloads'

# %%
os.chdir('C:/Users/HP/Desktop')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop'

# %%
school = pd.read_csv("MA_Public_Schools_2017.csv")

# %%
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1861 entries, 0 to 1860
# Columns: 302 entries, School Code to District_Progress and Performance Index (PPI) - High Needs Students
# dtypes: float64(265), int64(19), object(18)
# memory usage: 4.3+ MB

# %%
school.head()
# Out:
#    School Code                     School Name    School Type   Function  \
# 0        10505                   Abington High  Public School  Principal
# 1        10003  Beaver Brook Elementary School  Public School  Principal
# 2        10002        Center Elementary School  Public School  Principal
# 3        10405            Frolio Middle School  Public School  Principal
# 4        10015     Woodsdale Elementary School  Public School  Principal
#
#            Contact Name            Address 1 Address 2      Town State   Zip  \
# 0  Teresa Sullivan-Cruz   201 Gliniewicz Way       NaN  Abington    MA  2351
# 1       Catherine Zinni  1 Ralph Hamlin Lane       NaN  Abington    MA  2351
# 2        Lora Monachino   201 Gliniewicz Way       NaN  Abington    MA  2351
# 3    Matthew MacCurtain   201 Gliniewicz Way       NaN  Abington    MA  2351
# 4        Jonathan Hawes  128 Chestnut Street       NaN  Abington    MA  2351
#
# ...

# %%
school.isnull().sum()
# Out:
# School Code                                                               0
# School Name                                                               0
# School Type                                                               0
# Function                                                                  0
# Contact Name                                                              0
# Address 1                                                                 0
# Address 2                                                              1831
# Town                                                                      0
# State                                                                     0
# Zip                                                                       0
# Phone                                                                     0
# Fax                                                                       0
# ...

# %%
school.dtypes
# Out:
# School Code                                                              int64
# School Name                                                             object
# School Type                                                             object
# Function                                                                object
# Contact Name                                                            object
# Address 1                                                               object
# Address 2                                                               object
# Town                                                                    object
# State                                                                   object
# Zip                                                                      int64
# Phone                                                                   object
# Fax                                                                     object
# ...

# %%
school.shape
# Out:
# (1861, 302)

# %%
school['Town'].value_counts()[:20].plot(kind='bar')

# %%
school['School Type'].value_counts()[:20].plot(kind='bar')

# %%
school['Accountability and Assistance Level'].value_counts()[:20].plot(kind='bar')

# %%
school['District_Accountability and Assistance Level'].value_counts()[:20].plot(kind='pie')

# %%
school['School Accountability Percentile (1-99)'].value_counts()[:20].plot(kind='hist')

# %%
# %of high needs and %of economically disadvantaged shows similar distribution

sns.distplot(school["% High Needs"], hist=False, label="Function")
sns.distplot(school["% Economically Disadvantaged"], hist=False, label="disadvantaged")
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.

# %%
# There are too many District Names which are  not nice to be the factors for devision. 
sns.countplot(data=school, x="District Name")

# %%
sns.lmplot(data=school, x="Average Salary", y="% Economically Disadvantaged", fit_reg=False, hue="District_Accountability and Assistance Level")

# %%
school['Progress and Performance Index (PPI) - All Students'].plot(kind='hist')

# %%
#Then how about college, especially private Two-year which is expected to have high tuition. 
sns.lmplot(data=school, x="% Economically Disadvantaged", y="% Private Two-Year", fit_reg=False, hue="Accountability and Assistance Level")

# %%
school['Contact Name'].value_counts()[:10].plot(kind='bar')

# %%
sns.lmplot(data=school, x="% Economically Disadvantaged", y="% MCAS_10thGrade_English_W/F", fit_reg=False, hue="Accountability and Assistance Level")
sns.lmplot(data=school, x="% Economically Disadvantaged", y="% MCAS_10thGrade_English_W/F", fit_reg=False, hue="Accountability and Assistance Level")
